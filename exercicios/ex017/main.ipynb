# %%
# %pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# importação do gemini

# %%
# Import the Python SDK
import google.generativeai as genai

GOOGLE_API_KEY='AIzaSyASktxnPAMbXctDimqvHS1UMFIKlnRmqPE'
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# lista de modelos disponível

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# configuração de generação

# %%
generation_config = {
    'candidate_count': 1,
    'temperature': 0.8
}

# %% [markdown]
# configuração de segurança

# %%
safety_settings = {
    'HARASSMENT': 'BLOCK_NONE',
    'HATE': 'BLOCK_NONE',
    'SEXUAL': 'BLOCK_NONE',
    'DANGEROUS': 'BLOCK_NONE'
    }

# %% [markdown]
# inserindo as configurações no modelo

# %%
model = genai.GenerativeModel(model_name='gemini-1.0-pro',
                              generation_config=generation_config,
                              safety_settings=safety_settings)

# %% [markdown]
# criando um chat

# %%
chat = model.start_chat(history=[])

# %% [markdown]
# criando o prompt para o chat funcionar

# %%
prompt = input('Esperando prompt: ')

while prompt != 'fim':
  response = chat.send_message(prompt)
  print('Resposta: \n\n', response.text, '\n')
  prompt = input('Esperando prompt: ')
